# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\vlsan\\OneDrive\\Escritorio\\Documentos\\GitHub\\SIC2024'

# %% [markdown]
# <h1><center> APP para LateX (VisionLaTex)</center></h1>
# <ol>
# <li> <em><strong>Necesidad del cliente</strong></em>. Estudio y análisis del público para detectar los problemas con el producto o servicio.
# Definir las necesidades del usuario en función de la información obtenida.</li>
#
# Necesidades:
#     <ol>
# <li> Herramienta Intuitiva (Cam Scaner / Mathway /GeoGebra)... UX</li>
# <li> Accesibilidad (?? - Correo institucional, para creación de banco de datos)</li>
# <li> Portabilidad... Windows / Mac / Linux / Android</li>
# <li> Facil de enlazar con los otros IDE/Programas de desarrollo de LaTeX...</li>
#     </ol>
# Algunas cosas a tener en cuenta:
#     <ol>
# <li> Conocimiento de la herramienta...</li>
# <li> Experiencia de Usuario no satisfecha...</li>
# <li> Existencia de herramientas alternas... (<b>importante!!</b>)</li>
# <li> Incumplimiento de expectativa...</li>
#     </ol>
#
# <li><em><strong>Detección de oportunidad</strong></em>. Definidas estas necesidades, detectar la oportunidad de negocio que solventará los problemas del usuario.</li>
# La APP, de notas a LaTex, de fotos a LaTex, de pdf a LaTex, de .doc a LaTex,de .excel a LaTex???
#
# <li> <em><strong>Ideación de soluciones.</strong></em> Estudio de ideas y posibilidades sobre cómo abordar el problema existente en el mercado.</li>
# APP  portable, rapidad e intuitiva...
# <li> <em><strong>Priorización de la solución.</strong></em> Tras el análisis se elige una solución y se prioriza su desarrollo con el objetivo de conseguir un producto mínimo viable.</li>
# Modelo de (Documento) a Codigo LAtex! (ejecutar o solo codigo)
# <li>
# <strong><em>Construcción del producto mínimo viable según hipótesis.</strong></em> Desarrollo del producto y sus características atendiendo al aprendizaje extraído del análisis y estudio previo.</li>
# Archivos a latex
# <li><strong><em>Medición de resultados.</strong></em> Tras el lanzamiento al mercado del producto mínimo para testarlo, se recopila y analiza el 'feedback' aportado por los usuarios. Después, se adapta el producto al mismo, mejorando sus características.</li>
# Sitio Web, Encuestas, ??
# <li><strong><em>Aprendizaje de errores y detección de fortalezas.</strong></em> El análisis y el estudio continuo de todas las fases del proceso de desarrollo del método 'Lean Startup' aportará información sobre los fallos a evitar y también sobre los aspectos positivos que incluir en otros.</li>
#
# Sobre la Marcha...
# <li><strong><em>Validación. </strong></em>Cuando se llega al producto final, en función de los análisis obtenidos, se decide si este cumple con las expectativas de mercado.</li>
# <li><strong><em>Iteración.</strong></em> Repetir el proceso de mejora tantas veces como sea necesario para afinar el producto final.</li>
# <li><strong><em>Decisión de pivotar.</strong></em> Si, cumplidas estas etapas, se detecta que el producto o servicio no cumple los objetivos que demanda el mercado, la opción más conveniente es pivotar, es decir, cambiar aspectos claves del negocio para que encaje en el mercado.</li>

# %% [raw]
# ---
# title: "Quarto Basics"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ## Polar Axis
#
# For a demonstration of a line plot on a polar axis, see @fig-polar.

# %%
#| label: fig-polar
#| fig-cap: "A line plot on a polar axis"

import numpy as np
import matplotlib.pyplot as plt

r = np.arange(0,4 , 0.01)
theta = 2 * np.pi * r
fig, ax = plt.subplots(
  subplot_kw = {'projection': 'polar'} 
)
ax.plot(theta, r)
ax.set_rticks([0.5, 1, 1.5, 2])
ax.grid(True)
plt.show()
